# %%
from finetuning_flow import main
# Out:
# WARNING:tensorflow:From C:\Users\MAGIC\anaconda3\envs\survey_sunny\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
configs = [
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xc_config_IoU01.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xc_config_IoU03.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xc_config_IoU05.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xc_config_IoU07.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xcs_config_IoU01.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xcs_config_IoU03.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xcs_config_IoU05.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xcs_config_IoU07.yaml"
    
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfs_config_IoU01.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfs_config_IoU03.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfs_config_IoU05.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfs_config_IoU07.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfs_config_IoU09.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xf_config_IoU01.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xf_config_IoU03.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xf_config_IoU05.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xf_config_IoU07.yaml",
#     r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xf_config_IoU09.yaml"
    
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfc_frcnn03_craft02.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfc_frcnn03_craft03.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfc_frcnn03_craft04.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfcs_frcnn03_craft02.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfcs_frcnn03_craft03.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfcs_frcnn03+_craft04.yaml",
    
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfc_frcnn04_craft02.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfc_frcnn04_craft03.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfc_frcnn04_craft04.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfcs_frcnn04_craft02.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfcs_frcnn04_craft03.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfcs_frcnn04_craft04.yaml",
    
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfc_frcnn05_craft02.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfc_frcnn05_craft03.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfc_frcnn05_craft04.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfcs_frcnn05_craft02.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfcs_frcnn05_craft03.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfcs_frcnn05_craft04.yaml",
    
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfc_frcnn06_craft02.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfc_frcnn06_craft03.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfc_frcnn06_craft04.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfcs_frcnn06_craft02.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfcs_frcnn06_craft03.yaml",
    r"C:\Users\MAGIC\Ching\survey\plan\OCR\8\privateEasyOCR\training\recognizer\config_files\xfcs_frcnn06_craft04.yaml",
]
    
for config in configs:
     main(config)
# Out:
#  experiment_name : frcnn03_craft02_xfc
#  DS_log_level : INFO
#  FT_log_level : INFO
#  training_config :
# 	 skeleton : ['ch_tra']
# 	 model_ckpt :
# 	 lr : 1.0
# 	 rho : 0.95
# 	 eps : 1e-08
# 	 freeze_FeatureExtraction : True
# 	 freeze_SequenceModeling : False
# 	 training_episode : 250
# 	 grad_clip : 5
# 	 learning_rate_reduce_factor : 0.3
# 	 minimum_learning_rate : 1e-05
# 	 patience : 5
# 	 save_freq : 5
#  training_data_config :
# 	 train_data : ['./all_data/frcnn03_craft02/xfc/train']
# 	 label_max_length : 34
# 	 workers : 6
# 	 batch_size : 32
# 	 prefetch_factor : 512
# 	 shuffle : True
# 	 imgH : 64
# 	 imgW : 600
# 	 rgb : Fasle
# 	 contrast_adjust : 0.0
# 	 sensitive : True
# 	 PAD : True
# 	 keep_ratio_with_pad : False
#  validation_data_config :
# 	 valid_data : ['./all_data/frcnn03_craft02/xfc/val']
# 	 label_max_length : 34
# 	 workers : 6
# 	 batch_size : 32
# 	 prefetch_factor : 512
# 	 shuffle : False
# 	 imgH : 64
# 	 imgW : 600
# 	 rgb : Fasle
# ...
